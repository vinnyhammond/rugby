# %%
import matplotlib.pyplot as plt
import os

from matplotlib.patches import Arc


#Create figure
fig=plt.figure()
fig.set_size_inches(12, 7)
ax=fig.add_subplot(1,1,1)





#LHS Dead Ball Vertical
plt.plot([-10,-10],[0,68], color="black",linewidth=1.5)
#RHS Dead Ball Vertical
plt.plot([110,110],[68,0], color="black",linewidth=1.5)


#LHS Try Line Vertical
plt.plot([0,0],[0,68], color="black",linewidth=1.5)
#RHS Try Line Vertical
plt.plot([100,100],[68,0], color="black",linewidth=1.5)


#Upper Line Touch Line Horizontal
plt.plot([-10,110],[68,68], color="black")
#Lower Line Touch Line Horizontal
plt.plot([110,-10],[0,0], color="black")


#Half Way Line
plt.plot([50,50],[0,68], color="black",linewidth=1.5)
#22m Line - LHS
plt.plot([22,22],[0,68], color="black",linewidth=1.5)
#22m Line - RHS
plt.plot([78,78],[0,68], color="black",linewidth=1.5)


#Pitch Markings - Dashes along Top 5m Line - Remove as desired
plt.plot([5,10],[63,63], color="grey",linewidth=1)
plt.plot([19.5,24.5],[63,63], color="grey",linewidth=1)
#plt.plot([47.5,52.5],[63,63], color="grey")
plt.plot([37.5,42.5],[63,63], color="grey",linewidth=1)
plt.plot([57.5,62.5],[63,63], color="grey",linewidth=1)
plt.plot([75.5,80.5],[63,63], color="grey",linewidth=1)
plt.plot([90,95],[63,63], color="grey",linewidth=1)

#Pitch Markings - Dashes along Top 15m Line - Remove as desired
plt.plot([5,10],[53,53], color="grey",linewidth=1)
plt.plot([19.5,24.5],[53,53], color="grey",linewidth=1)
#plt.plot([47.5,52.5],[53,53], color="grey")
plt.plot([37.5,42.5],[53,53], color="grey",linewidth=1)
plt.plot([57.5,62.5],[53,53], color="grey",linewidth=1)
plt.plot([75.5,80.5],[53,53], color="grey",linewidth=1)
plt.plot([90,95],[53,53], color="grey",linewidth=1)

#Pitch Markings - Dashes along Btm 5m Line - Remove as desired
plt.plot([5,10],[5,5], color="grey",linewidth=1)
plt.plot([19.5,24.5],[5,5], color="grey",linewidth=1)
#plt.plot([47.5,52.5],[5,5], color="grey",linewidth=1)
plt.plot([37.5,42.5],[5,5], color="grey",linewidth=1)
plt.plot([57.5,62.5],[5,5], color="grey",linewidth=1)
plt.plot([75.5,80.5],[5,5], color="grey",linewidth=1)
plt.plot([90,95],[5,5], color="grey",linewidth=1)

#Pitch Markings - Dashes along Btm 15m Line - Remove as desired
plt.plot([5,10],[15,15], color="grey",linewidth=1)
plt.plot([19.5,24.5],[15,15], color="grey",linewidth=1)
#plt.plot([47.5,52.5],[15,15], color="grey")
plt.plot([37.5,42.5],[15,15], color="grey",linewidth=1)
plt.plot([57.5,62.5],[15,15], color="grey",linewidth=1)
plt.plot([75.5,80.5],[15,15], color="grey",linewidth=1)
plt.plot([90,95],[15,15], color="grey",linewidth=1)




#5m Vertical Dashes LHS
plt.plot([5,5],[2.5,7.5], color="grey",linewidth=1)
plt.plot([5,5],[12.5,17.5], color="grey",linewidth=1)
plt.plot([5,5],[60.5,65.5], color="grey",linewidth=1)
plt.plot([5,5],[50.5,55.5], color="grey",linewidth=1)

#5m Vertical Dashes RHS
plt.plot([95,95],[2.5,7.5], color="grey",linewidth=1)
plt.plot([95,95],[12.5,17.5], color="grey",linewidth=1)
plt.plot([95,95],[60.5,65.5], color="grey",linewidth=1)
plt.plot([95,95],[50.5,55.5], color="grey",linewidth=1)

#10m Vertical Dashes LHS
plt.plot([40,40],[2.5,7.5], color="grey",linewidth=1)
plt.plot([40,40],[12.5,17.5], color="grey",linewidth=1)
plt.plot([40,40],[60.5,65.5], color="grey",linewidth=1)
plt.plot([40,40],[50.5,55.5], color="grey",linewidth=1)

#10m Vertical Dashes RHS
plt.plot([60,60],[2.5,7.5], color="grey",linewidth=1)
plt.plot([60,60],[12.5,17.5], color="grey",linewidth=1)
plt.plot([60,60],[60.5,65.5], color="grey",linewidth=1)
plt.plot([60,60],[50.5,55.5], color="grey",linewidth=1)




#Half Way Spot
plt.plot([49.5,50.5],[34,34], color="grey")


lhsbpost = plt.Circle((0,31),.5,color="black")
lhstpost = plt.Circle((0,37),.5,color="black")
rhsbpost = plt.Circle((100,31),.5,color="black")
rhstpost = plt.Circle((100,37),.5,color="black")
ax.add_patch(lhsbpost)
ax.add_patch(lhstpost)
ax.add_patch(rhsbpost)
ax.add_patch(rhstpost)




plt.plot([60,60],[25,29], color="grey",linewidth=1)
plt.plot([40,40],[25,29], color="grey",linewidth=1)
plt.plot([40,40],[39,43], color="grey",linewidth=1)
plt.plot([60,60],[39,43], color="grey",linewidth=1)

plt.plot([5,5],[25,29], color="grey",linewidth=1)
plt.plot([95,95],[25,29], color="grey",linewidth=1)
plt.plot([5,5],[39,43], color="grey",linewidth=1)
plt.plot([95,95],[39,43], color="grey",linewidth=1)







#Display Pitch
plt.show()
